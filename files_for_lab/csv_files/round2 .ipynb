# %%
import pandas as pd

file1 = pd.read_csv('marketing_customer_analysis.csv')

import matplotlib as plot

# %%
file1.shape
# Out:
# (10910, 26)

# %%
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file1.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
cols = []
for colname in file1.columns:
    cols.append(colname.lower())
file1.columns = cols

# %%
file1.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
file1.head(10)
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
# 5           5  HO81102         NaN              4745.181764      NaN
# 6           6  IW72280  California              5035.035257       No
# 7           7  IH64929  California              4956.247235       No
# 8           8  FM55990  California              5989.773931      Yes
# 9           9  QX31376      Oregon             17114.328150       No
#
#    coverage             education effective to date employmentstatus gender  \
# 0     Basic               College           2/18/11         Employed      M
# ...

# %%
missing_values_count = file1.isnull().sum()

# %%
missing_values_count
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
missing=file1[["customer","state", "response","months since last claim", "number of open complaints","vehicle class", "vehicle size"]]
missing.head(20)
# Out:
#    customer       state response  months since last claim  \
# 0   DK49336     Arizona       No                      7.0
# 1   KX64629  California       No                      3.0
# 2   LZ68649  Washington       No                     34.0
# 3   XL78013      Oregon      Yes                     10.0
# 4   QA50777      Oregon       No                      NaN
# 5   HO81102         NaN      NaN                      2.0
# 6   IW72280  California       No                      8.0
# 7   IH64929  California       No                     35.0
# 8   FM55990  California      Yes                     33.0
# 9   QX31376      Oregon       No                     19.0
# 10  HG93801     Arizona       No                     13.0
# 11  GE63585         NaN      NaN                      5.0
# 12  EO51920      Oregon       No                     24.0
# 13  KR82385  California       No                     25.0
# 14  TL59568     Arizona       No                      6.0
# ...

# %%
missing_values_count = missing.isnull().sum()
missing_values_count
# Out:
# customer                       0
# state                        631
# response                     631
# months since last claim      633
# number of open complaints    633
# vehicle class                622
# vehicle size                 622
# dtype: int64

# %%
file1["state"].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
file1["state"]=file1["state"].fillna("California")

# %%
file1["state"].value_counts(dropna=False)
# Out:
# California    4183
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %%
missing_values_count = file1.isnull().sum()
missing_values_count
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
file1["vehicle type"].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: vehicle type, dtype: int64

# %%
file1["vehicle type"]=file1["vehicle type"].fillna("M")

# %%
missing_values_count = file1.isnull().sum()
missing_values_count
# Out:
# unnamed: 0                         0
# customer                           0
# state                              0
# customer lifetime value            0
# response                         631
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          633
# months since policy inception      0
# number of open complaints        633
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    622
# vehicle size                     622
# ...

# %%
file1["months since last claim"].value_counts(dropna=False)
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
round(file1["months since last claim"].median())
# Out:
# 14

# %%
file1["months since last claim"]=file1["months since last claim"].fillna(15.0)
file1["months since last claim"].value_counts(dropna=False)
# Out:
# 15.0    956
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 23.0    276
# 19.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
file1["number of open complaints"].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
file1["number of open complaints"]=file1["number of open complaints"].fillna("0")

# %%
missing_values_count = file1.isnull().sum()
missing_values_count
# Out:
# unnamed: 0                         0
# customer                           0
# state                              0
# customer lifetime value            0
# response                         631
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim            0
# months since policy inception      0
# number of open complaints          0
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    622
# vehicle size                     622
# ...

# %%
file1["response"].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64

# %%
file1["response"]=file1["response"].fillna("No")

# %%
missing_values_count = file1.isnull().sum()
missing_values_count
# Out:
# unnamed: 0                         0
# customer                           0
# state                              0
# customer lifetime value            0
# response                           0
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim            0
# months since policy inception      0
# number of open complaints          0
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    622
# vehicle size                     622
# ...

# %%
file1["vehicle class"].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
file1["vehicle size"].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle size, dtype: int64

# %%
file1["vehicle class"]=file1["vehicle class"].fillna("Four-Door Car")
file1["vehicle size"]=file1["vehicle size"].fillna("Medsize")

# %%
file1.head(10)
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
# 5           5  HO81102  California              4745.181764       No
# 6           6  IW72280  California              5035.035257       No
# 7           7  IH64929  California              4956.247235       No
# 8           8  FM55990  California              5989.773931      Yes
# 9           9  QX31376      Oregon             17114.328150       No
#
#    coverage             education effective to date employmentstatus gender  \
# 0     Basic               College           2/18/11         Employed      M
# ...

# %%
file1['effective to date'] = pd.to_datetime(file1['effective to date'])
file1['month'] = file1['effective to date'].dt.month
display(file1)
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
q1_data = file1[(file1['month'] >= 1) & (file1['month'] <= 3)]
display(q1_data)
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1.shape
# Out:
# (10910, 27)

# %%
display(file1)
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
## start of round 3

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed: 0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer lifetime value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective to date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location code                  10910 non-null  object
# ...

# %%
file1.describe()
# Out:
#          unnamed: 0  customer lifetime value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly premium auto  months since last claim  \
# count          10910.000000             10910.000000
# mean              93.196059                15.140422
# std               34.442532                 9.783582
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# 50%               83.000000                15.000000
# 75%              109.000000                23.000000
# ...

# %%
##file1['response'].value_counts()[:].plot(kind='barh')
import seaborn as sns

sns.countplot(x=file1["response"])
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
sns.countplot(data=file1, x="sales channel", hue="response")
# Out:
# <AxesSubplot:xlabel='sales channel', ylabel='count'>

# %%
x1=file1["response"]
x2=file1["total claim amount"]

# %%
import matplotlib.pyplot as plt
# plot data
fig, ax = plt.subplots(figsize=(15,7))

plt.hist([x1,x2],label=["response","total claim amount"], bins=10, alpha=0.5)
plt.legend(borderpad=0.5,fontsize=20)
plt.show()

# %%
x3=file1["income"]

# %%
# plot data
fig, ax = plt.subplots(figsize=(20,10))

plt.hist([x1,x3],label=["response","income"], bins=10, alpha=0.5)
plt.legend(borderpad=0.5,fontsize=20)
plt.show()

# %%
##Lab | Customer Analysis Round 4

# %%
import numpy as np

# %%
numericdf = file1.select_dtypes(include=np.number)

# %%
type(numericdf)
# Out:
# pandas.core.frame.DataFrame

# %%
objektdf = file1.select_dtypes(include=object)

# %%
type(objektdf)
# Out:
# pandas.core.frame.DataFrame

# %%
display(objektdf)
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877  California       No     Basic  Bachelor       Unemployed
#
#       gender location code marital status number of open complaints  \
# ...

# %%
display(numericdf)
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
numericdf=numericdf.drop('unnamed: 0', axis=1)

# %%
numericdf.describe().T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10910.0     15.140422      9.783582
# months since policy inception  10910.0     48.091934     27.940675
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
# month                          10910.0      1.466728      0.498915
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     7.000000     15.000000
# ...

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

sns.scatterplot(x='number of policies',y='total claim amount',data=numericdf)
plt.show()

# %%
numericdf['income'].corr(numericdf['total claim amount'])
# Out:
# -0.35414122250987995

# %%
display(numericdf)
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
col=numericdf.columns

for i in col:
        numericdf.hist(column=i , bins=20)

# %%
numericdf.hist(column='total claim amount', bins=20);

# %%
correlations_matrix = numericdf.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()
